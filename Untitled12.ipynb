# %% [markdown]
# <a href="https://colab.research.google.com/github/Razeeeeeeeeeee/DSPLab/blob/master/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install guidance

# %%
OPEN_API_KEY="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"

# %%
from guidance import models,gen,select, user,system, assistant
gpt=models.OpenAI("gpt-3.5-turbo-0125",api_key=OPEN_API_KEY)

# %%
with system():
  gpt+="""Imagine three experts with exceptional analysis skills are collaboratively answering a question using the tree of thoughts method. Each expert thinks about different aspects. Each expert will share their thought process in detail, taking into account the previous thoughts of others and admitting any errors. They will iteratively refine and expand upon each other's ideas, giving credit where it's due. The process continues until a conclusive answer is found. The task is:

          Rate the following emails of different clients as an expert Assistant to the Customer relation manager would. rank it on a scale of 1 to 10, with 10 being a satisfied customer and 1 being a customer at risk. Rate it in such a way that the score is an indicator of the priority of the clients. A score of 1 indicates that the client is at risk and is not satisfied with the product and is looking for alternatives.A score of 10 indicates satisfied customer, who is excited about the product. A score of 5 would indicate a neutral customer.
          The score would help alert the customer relation manager of a risk of losing a client and would help him to avoid it. It would also help him focus on providing better services
          Think carefully and logically, explaining your answer.

          """
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>Imagine three experts with exceptional analysis skills are collaboratively answering a question using the tree of thoughts method. Each expert thinks about different aspects. Each expert will share their thought process in detail, taking into account the previous thoughts of others and admitting any errors. They will iteratively refine and expand upon each other&#x27;s ideas, giving credit where it&#x27;s due. The process continues until
# ...

# %%
query = """Subject: Urgent: Concerns About Software Usage
Hi Mary,
I hope you're doing well. I wanted to reach out with some concerns about our use of WidgetMaster. We've been evaluating our software stack and unfortunately, we're considering alternatives due to some challenges we've faced.
Main pain points:
Integration: WidgetMaster doesn't integrate well with our systems, causing inefficiencies.
Performance: We've experienced slow load times and occasional crashes.
Customization: Limited options for tailoring the software to our needs.
Support: Response times for support have been slower than ideal.
We're exploring other solutions to better align with our needs. We value our relationship and want to be transparent about our decision-making process.
Let me know if you'd like to discuss further."""

# %%
with user():
  gpt+=f"""{query}"""
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>Imagine three experts with exceptional analysis skills are collaboratively answering a question using the tree of thoughts method. Each expert thinks about different aspects. Each expert will share their thought process in detail, taking into account the previous thoughts of others and admitting any errors. They will iteratively refine and expand upon each other&#x27;s ideas, giving credit where it&#x27;s due. The process continues until
# ...

# %%
with assistant():
    gpt += gen(max_tokens=1000)
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>Imagine three experts with exceptional analysis skills are collaboratively answering a question using the tree of thoughts method. Each expert thinks about different aspects. Each expert will share their thought process in detail, taking into account the previous thoughts of others and admitting any errors. They will iteratively refine and expand upon each other&#x27;s ideas, giving credit where it&#x27;s due. The process continues until
# ...

# %%
with user():
  gpt+="why a 3 and not 2"
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>Imagine three experts with exceptional analysis skills are collaboratively answering a question using the tree of thoughts method. Each expert thinks about different aspects. Each expert will share their thought process in detail, taking into account the previous thoughts of others and admitting any errors. They will iteratively refine and expand upon each other&#x27;s ideas, giving credit where it&#x27;s due. The process continues until
# ...

# %%
with assistant():
   gpt += gen(max_tokens=1000)
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>Imagine three experts with exceptional analysis skills are collaboratively answering a question using the tree of thoughts method. Each expert thinks about different aspects. Each expert will share their thought process in detail, taking into account the previous thoughts of others and admitting any errors. They will iteratively refine and expand upon each other&#x27;s ideas, giving credit where it&#x27;s due. The process continues until
# ...

# %%
with user():
  gpt+="""Subject: Concerns Regarding Our Partnership
Hi Mary,
I hope you're doing well. I wanted to share some concerns we've been experiencing with our partnership.
Lack of Proactive Communication
Decline in Service Quality
Strategic Misalignment
These issues have us considering alternatives. Can we schedule a discussion to address them?
Looking forward to your response.
Best,
Sarah
"""
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>Imagine three experts with exceptional analysis skills are collaboratively answering a question using the tree of thoughts method. Each expert thinks about different aspects. Each expert will share their thought process in detail, taking into account the previous thoughts of others and admitting any errors. They will iteratively refine and expand upon each other&#x27;s ideas, giving credit where it&#x27;s due. The process continues until
# ...

# %%
with assistant():
  gpt+=gen(max_tokens=10000)
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>Imagine three experts with exceptional analysis skills are collaboratively answering a question using the tree of thoughts method. Each expert thinks about different aspects. Each expert will share their thought process in detail, taking into account the previous thoughts of others and admitting any errors. They will iteratively refine and expand upon each other&#x27;s ideas, giving credit where it&#x27;s due. The process continues until
# ...

# %%
with user():
  gpt+="""Subject: Feedback and Usage Update
Hi Mary,
I hope you're doing well. Just wanted to share some feedback on our experience with ProductX.
Overall, it's been great. We're particularly impressed with the analytics dashboard, which has been invaluable for tracking our marketing campaigns. Your recent updates have also been noted and appreciated.
ProductX has become integral to our operations, and we're excited to keep using it.
Thanks for your support.
Best,
Bob

"""
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>Imagine three experts with exceptional analysis skills are collaboratively answering a question using the tree of thoughts method. Each expert thinks about different aspects. Each expert will share their thought process in detail, taking into account the previous thoughts of others and admitting any errors. They will iteratively refine and expand upon each other&#x27;s ideas, giving credit where it&#x27;s due. The process continues until
# ...

# %%
with assistant():
  gpt+=gen(max_tokens=1000)
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>Imagine three experts with exceptional analysis skills are collaboratively answering a question using the tree of thoughts method. Each expert thinks about different aspects. Each expert will share their thought process in detail, taking into account the previous thoughts of others and admitting any errors. They will iteratively refine and expand upon each other&#x27;s ideas, giving credit where it&#x27;s due. The process continues until
# ...

# %%
with user():
  gpt+="""Subject: Urgent: Concerns About Software Usage
Hi Mary,
I hope you're doing well. I wanted to reach out with some concerns about our use of WidgetMaster. We've been evaluating our software stack and unfortunately, we're considering alternatives due to some challenges we've faced.
Main pain points:
Integration: WidgetMaster doesn't integrate well with our systems, causing inefficiencies.
Performance: We've experienced slow load times and occasional crashes.
Customization: Limited options for tailoring the software to our needs.
Support: Response times for support have been slower than ideal.
We're exploring other solutions to better align with our needs. We value our relationship and want to be transparent about our decision-making process.
Let me know if you'd like to discuss further.
Best,
"""

with assistant():
  gpt+=gen(max_tokens=1000)
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>Imagine three experts with exceptional analysis skills are collaboratively answering a question using the tree of thoughts method. Each expert thinks about different aspects. Each expert will share their thought process in detail, taking into account the previous thoughts of others and admitting any errors. They will iteratively refine and expand upon each other&#x27;s ideas, giving credit where it&#x27;s due. The process continues until
# ...

# %%
with user():
  gpt+="""Subject: Weekly Update and Feedback
Hi Mary,
I hope you're doing well. We wanted to provide some feedback and updates on our experience with your AI SaaS platform over the past week. We've noticed a significant improvement in response times and accuracy in our chatbot. However, there's still room for improvement in handling complex queries. Could we schedule a call to discuss this further?
Best regards,
David

"""

with assistant():
  gpt+=gen(max_tokens=10000)
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>Imagine three experts with exceptional analysis skills are collaboratively answering a question using the tree of thoughts method. Each expert thinks about different aspects. Each expert will share their thought process in detail, taking into account the previous thoughts of others and admitting any errors. They will iteratively refine and expand upon each other&#x27;s ideas, giving credit where it&#x27;s due. The process continues until
# ...

# %%
with user():
  gpt+="""Subject: Billing and Subscription Status
Hi Mary,
We wanted to check in on the status of our billing and subscription with your AI SaaS platform. Could you please provide an update on our current subscription and any upcoming renewals or changes to our plan?
Thank you for your assistance,
Ryan
"""

with assistant():
  gpt+=gen(max_tokens=10000)
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2); align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>Imagine three experts with exceptional analysis skills are collaboratively answering a question using the tree of thoughts method. Each expert thinks about different aspects. Each expert will share their thought process in detail, taking into account the previous thoughts of others and admitting any errors. They will iteratively refine and expand upon each other&#x27;s ideas, giving credit where it&#x27;s due. The process continues until
# ...
